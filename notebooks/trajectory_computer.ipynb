# %% [markdown]
# ##### The point of the trajectory computer is to take the output of the archive_reader

# %% [markdown]
# Tell python where to find archive_reader.py, and then call it.

# %% [markdown]
# 'sys' allows us to talk to the system, 'os' allows us to talk to the operating system, and 'datetime' is ...

# %%
import sys
import os
from datetime import datetime, timezone
